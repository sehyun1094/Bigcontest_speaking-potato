# %%
import numpy as np
import pandas as pd

# %%
user_spec = pd.read_csv('user_spec.csv')
loan_result = pd.read_csv('loan_result.csv')
log_data = pd.read_csv('log_data.csv')

# %%
loan_result.isnull().sum()
# Out:
# application_id                 0
# loanapply_insert_time          0
# bank_id                        0
# product_id                     0
# loan_limit                  7495
# loan_rate                   7495
# is_applied               3257239
# dtype: int64

# %%
loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied
# 0         42000000.0       13.6         NaN
# 1         24000000.0       17.9         NaN
# ...

# %%
user_spec[user_spec["application_id"] == 1428218]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 348491         1428218   478802        1965       1 2022-06-03 12:01:47
#
#         credit_score  yearly_income   income_type company_enter_month  \
# 348491           610       45000000  EARNEDINCOME          2019-03-01
#
#        employment_type houseown_type  desired_amount purpose  \
# 348491             정규직        기타가족소유      50000000.0    대환대출
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 348491                         0.0                                  NaN
#
#         existing_loan_cnt  existing_loan_amt
# 348491                2.0         56000000.0

# %%
loan_result[loan_result["application_id"] == 1428218]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 13527324         1428218   2022-06-03 12:01:47       38         134
# 13527325         1428218   2022-06-03 12:01:47       47          47
# 13527326         1428218   2022-06-03 12:02:11       49          39
# 13527327         1428218   2022-06-03 12:02:05       22         164
# 13527328         1428218   2022-06-03 12:01:47       30         114
# 13527329         1428218   2022-06-03 12:01:47       50         142
# 13527330         1428218   2022-06-03 12:02:07       29          75
# 13527331         1428218   2022-06-03 12:01:48       31         224
# 13527332         1428218   2022-06-03 12:01:57       47         138
# 13527333         1428218   2022-06-03 12:02:11       49         136
# 13527334         1428218   2022-06-03 12:01:49       11         118
# 13527335         1428218   2022-06-03 12:01:47       59         150
# 13527336         1428218   2022-06-03 12:01:47       62          48
# ...

# %%
import pandas as pd
data = pd.read_csv("../../../../../bigcontest/data/preprocessed/dat3.csv")

# %%
data.index = data["user_id"]

# %%
data.drop("user_id", axis = 1, inplace = True)

# %%
data.shape
# Out:
# (584636, 11)

# %%
from minisom import MiniSom
import bokeh
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon
import numpy as np
import pandas as pd

# %%
map_n= [n for n in range(2,6)]
para_sigma= [np.round(sigma*0.1,2) for sigma in range(1,10)]
para_learning_rate= [np.round(learning_rate*0.1,2) for learning_rate in range(1,10)]
indexxx = 0

#결과 값을 담을 리스트 res 생성
res = []
#모든 조합에 대해 모델 생성 및 qe,te값 계산
for n in map_n:
    for sigma in para_sigma:
        for lr in para_learning_rate:
            s_time = pd.Timestamp.now()
            indexxx += 1
            try:
                #랜덤으로 초기값을 설정하는 경우
                estimator = MiniSom(n,n,11,sigma =sigma, learning_rate = lr, topology='hexagonal',random_seed=0)
                estimator.random_weights_init(data.values)
                estimator.train(data.values,1000,random_order=True)
                qe = estimator.quantization_error(data.values)
                #te = estimator.topographic_error(data.values)
                winner_coordinates = np.array([estimator.winner(x) for x in data.values]).T
                cluster_index = np.ravel_multi_index(winner_coordinates,(n,n))
                
                res.append([str(n)+'x'+str(n),sigma,lr,'random_init',qe,len(np.unique(cluster_index))])                
            except ValueError as e:
                print(e)
            e_time = pd.Timestamp.now()
            print('\n총 소요시간:',e_time-s_time, indexxx)
# Out:
# 총 소요시간: 0 days 00:00:07.838330 1
#
# 총 소요시간: 0 days 00:00:07.768984 2
#
# 총 소요시간: 0 days 00:00:07.752110 3
#
# 총 소요시간: 0 days 00:00:07.815124 4
#
# 총 소요시간: 0 days 00:00:08.594513 5
#
# 총 소요시간: 0 days 00:00:07.924445 6
#
# 총 소요시간: 0 days 00:00:07.765548 7
#
# 총 소요시간: 0 days 00:00:07.733819 8
#
# 총 소요시간: 0 days 00:00:07.766592 9
#
# 총 소요시간: 0 days 00:00:07.702173 10
#
# 총 소요시간: 0 days 00:00:07.763493 11
#
# 총 소요시간: 0 days 00:00:07.735852 12
#
# 총 소요시간: 0 days 00:00:07.765191 13
#
# 총 소요시간: 0 days 00:00:12.874909 14
#
# 총 소요시간: 0 days 00:00:07.775113 15
#
# 총 소요시간: 0 days 00:00:07.750035 16
#
# 총 소요시간: 0 days 00:00:07.750017 17
#
# 총 소요시간: 0 days 00:00:07.734573 18
#
# 총 소요시간: 0 days 00:00:07.831016 19
#
# 총 소요시간: 0 days 00:00:07.750103 20
#
# 총 소요시간: 0 days 00:00:07.750012 21
#
# 총 소요시간: 0 days 00:00:07.765639 22
#
# 총 소요시간: 0 days 00:00:07.782262 23
#
# 총 소요시간: 0 days 00:00:07.773125 24
#
# 총 소요시간: 0 days 00:00:07.808168 25
#
# 총 소요시간: 0 days 00:00:08.177556 26
#
# 총 소요시간: 0 days 00:00:07.838473 27
#
# 총 소요시간: 0 days 00:00:07.756438 28
#
# 총 소요시간: 0 days 00:00:07.701536 29
#
# 총 소요시간: 0 days 00:00:07.764539 30
#
# 총 소요시간: 0 days 00:00:07.764612 31
#
# 총 소요시간: 0 days 00:00:07.767714 32
#
# 총 소요시간: 0 days 00:00:07.718812 33
#
# 총 소요시간: 0 days 00:00:07.788231 34
#
# 총 소요시간: 0 days 00:00:07.696176 35
#
# 총 소요시간: 0 days 00:00:12.856105 36
#
# 총 소요시간: 0 days 00:00:07.726181 37
#
# 총 소요시간: 0 days 00:00:07.748940 38
#
# 총 소요시간: 0 days 00:00:07.749021 39
#
# 총 소요시간: 0 days 00:00:07.750015 40
#
# 총 소요시간: 0 days 00:00:07.765597 41
#
# 총 소요시간: 0 days 00:00:07.766704 42
#
# 총 소요시간: 0 days 00:00:07.770278 43
#
# 총 소요시간: 0 days 00:00:07.763137 44
#
# 총 소요시간: 0 days 00:00:07.735337 45
#
# 총 소요시간: 0 days 00:00:07.795884 46
#
# 총 소요시간: 0 days 00:00:07.755739 47
#
# 총 소요시간: 0 days 00:00:07.809862 48
#
# 총 소요시간: 0 days 00:00:07.765071 49
#
# 총 소요시간: 0 days 00:00:07.788010 50
#
# 총 소요시간: 0 days 00:00:07.737454 51
#
# 총 소요시간: 0 days 00:00:07.748017 52
#
# 총 소요시간: 0 days 00:00:07.702181 53
#
# 총 소요시간: 0 days 00:00:07.755025 54
#
# 총 소요시간: 0 days 00:00:07.744067 55
#
# 총 소요시간: 0 days 00:00:07.763421 56
#
# 총 소요시간: 0 days 00:00:07.720167 57
#
# 총 소요시간: 0 days 00:00:12.826031 58
#
# 총 소요시간: 0 days 00:00:07.739816 59
#
# 총 소요시간: 0 days 00:00:07.749384 60
#
# 총 소요시간: 0 days 00:00:07.764655 61
#
# 총 소요시간: 0 days 00:00:07.787016 62
#
# 총 소요시간: 0 days 00:00:07.810879 63
#
# 총 소요시간: 0 days 00:00:07.863567 64
#
# 총 소요시간: 0 days 00:00:07.848886 65
#
# 총 소요시간: 0 days 00:00:07.881245 66
#
# 총 소요시간: 0 days 00:00:07.775044 67
#
# 총 소요시간: 0 days 00:00:07.816328 68
#
# 총 소요시간: 0 days 00:00:07.754157 69
#
# 총 소요시간: 0 days 00:00:07.762955 70
#
# 총 소요시간: 0 days 00:00:07.767524 71
#
# 총 소요시간: 0 days 00:00:07.743959 72
#
# 총 소요시간: 0 days 00:00:07.709963 73
#
# 총 소요시간: 0 days 00:00:07.764991 74
#
# 총 소요시간: 0 days 00:00:07.732385 75
#
# 총 소요시간: 0 days 00:00:07.718777 76
#
# 총 소요시간: 0 days 00:00:07.668730 77
#
# 총 소요시간: 0 days 00:00:07.762548 78
#
# 총 소요시간: 0 days 00:00:07.769424 79
#
# 총 소요시간: 0 days 00:00:12.816867 80
#
# 총 소요시간: 0 days 00:00:07.731395 81
#
# 총 소요시간: 0 days 00:00:07.873927 82
#
# 총 소요시간: 0 days 00:00:07.882358 83
#
#
# 총 소요시간: 0 days 00:00:08.704859 250
#
# 총 소요시간: 0 days 00:00:08.701572 251
#
# 총 소요시간: 0 days 00:00:08.676930 252
#
# 총 소요시간: 0 days 00:00:08.605249 253
#
# 총 소요시간: 0 days 00:00:08.693657 254
# C:\Users\25211-1\anaconda3\lib\site-packages\minisom.py:513: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(-2 * cross_term + input_data_sq + weights_flat_sq.T)
# 총 소요시간: 0 days 00:00:08.844384 255
#
# 총 소요시간: 0 days 00:00:08.862996 256
#
# 총 소요시간: 0 days 00:00:11.605393 257
#
# 총 소요시간: 0 days 00:00:14.250681 258
#
# 총 소요시간: 0 days 00:00:08.703283 259
#
# 총 소요시간: 0 days 00:00:08.700094 260
#
# 총 소요시간: 0 days 00:00:08.653146 261
#
# 총 소요시간: 0 days 00:00:08.556292 262
#
# 총 소요시간: 0 days 00:00:08.631019 263
#
# 총 소요시간: 0 days 00:00:08.536757 264
#
# 총 소요시간: 0 days 00:00:08.551051 265
#
# 총 소요시간: 0 days 00:00:08.706201 266
#
# 총 소요시간: 0 days 00:00:08.667709 267
#
# 총 소요시간: 0 days 00:00:08.619824 268
#
# 총 소요시간: 0 days 00:00:08.617606 269
#
# 총 소요시간: 0 days 00:00:08.584503 270
#
# 총 소요시간: 0 days 00:00:08.552064 271
#
# 총 소요시간: 0 days 00:00:08.537587 272
#
# 총 소요시간: 0 days 00:00:08.499945 273
#
# 총 소요시간: 0 days 00:00:08.548384 274
#
# 총 소요시간: 0 days 00:00:08.489144 275
#
# 총 소요시간: 0 days 00:00:08.566583 276
#
# 총 소요시간: 0 days 00:00:08.570650 277
#
# 총 소요시간: 0 days 00:00:08.524178 278
#
# 총 소요시간: 0 days 00:00:08.516770 279
#
# 총 소요시간: 0 days 00:00:08.518167 280
#
# 총 소요시간: 0 days 00:00:08.500403 281
#
# 총 소요시간: 0 days 00:00:08.531250 282
#
# 총 소요시간: 0 days 00:00:08.580870 283
#
# 총 소요시간: 0 days 00:00:08.583340 284
#
# 총 소요시간: 0 days 00:00:08.520828 285
#
# 총 소요시간: 0 days 00:00:08.531727 286
#
# 총 소요시간: 0 days 00:00:08.567821 287
#
# 총 소요시간: 0 days 00:00:08.564057 288
#
# 총 소요시간: 0 days 00:00:08.598339 289
#
# 총 소요시간: 0 days 00:00:08.568340 290
#
# 총 소요시간: 0 days 00:00:08.589598 291
#
# 총 소요시간: 0 days 00:00:08.498352 292
#
# 총 소요시간: 0 days 00:00:08.483378 293
#
# 총 소요시간: 0 days 00:00:08.498946 294
#
# 총 소요시간: 0 days 00:00:08.562534 295
#
# 총 소요시간: 0 days 00:00:08.492093 296
#
# 총 소요시간: 0 days 00:00:08.573506 297
#
# 총 소요시간: 0 days 00:00:08.583987 298
#
# 총 소요시간: 0 days 00:00:08.536455 299
#
# 총 소요시간: 0 days 00:00:08.471900 300
#
# 총 소요시간: 0 days 00:00:08.545244 301
#
# 총 소요시간: 0 days 00:00:08.518280 302
#
# 총 소요시간: 0 days 00:00:08.533474 303
#
# 총 소요시간: 0 days 00:00:08.531607 304
#
# 총 소요시간: 0 days 00:00:08.629861 305
#
# 총 소요시간: 0 days 00:00:08.499501 306
#
# 총 소요시간: 0 days 00:00:08.515812 307
#
# 총 소요시간: 0 days 00:00:08.490298 308
#
# 총 소요시간: 0 days 00:00:08.562494 309
#
# 총 소요시간: 0 days 00:00:08.476383 310
#
# 총 소요시간: 0 days 00:00:08.556942 311
#
# 총 소요시간: 0 days 00:00:08.552686 312
#
# 총 소요시간: 0 days 00:00:08.517949 313
#
# 총 소요시간: 0 days 00:00:08.531525 314
#
# 총 소요시간: 0 days 00:00:08.440202 315
#
# 총 소요시간: 0 days 00:00:08.495248 316
#
# 총 소요시간: 0 days 00:00:08.531240 317
#
# 총 소요시간: 0 days 00:00:08.551814 318
#
# 총 소요시간: 0 days 00:00:08.590743 319
#
# 총 소요시간: 0 days 00:00:08.530709 320
#
# 총 소요시간: 0 days 00:00:08.558002 321
#
# 총 소요시간: 0 days 00:00:08.489184 322
#
# 총 소요시간: 0 days 00:00:08.561908 323
#
# 총 소요시간: 0 days 00:00:08.476333 324

# %%
df_res = pd.DataFrame(res,columns=['map_size','sigma','learning_rate','init_method','qe','n_cluster'])

# %%
df_res[df_res['map_size'] == '2x2'].sort_values(by=['qe'],ascending=True, ignore_index=True)
# Out:
#    map_size  sigma  learning_rate  init_method        qe  n_cluster
# 0       2x2    0.4            0.1  random_init  0.772742          4
# 1       2x2    0.5            0.1  random_init  0.773078          4
# 2       2x2    0.1            0.1  random_init  0.773089          4
# 3       2x2    0.2            0.1  random_init  0.773089          4
# 4       2x2    0.3            0.1  random_init  0.773089          4
# ..      ...    ...            ...          ...       ...        ...
# 76      2x2    0.5            0.9  random_init  0.851557          4
# 77      2x2    0.6            0.9  random_init  0.851558          4
# 78      2x2    0.7            0.9  random_init  0.851563          4
# 79      2x2    0.8            0.9  random_init  0.851601          4
# 80      2x2    0.9            0.9  random_init  0.851848          4
#
# [81 rows x 6 columns]

# %%
df_res.sort_values(by=['qe'],ascending=True, ignore_index=True)
# Out:
#     map_size  sigma  learning_rate  init_method        qe  n_cluster
# 0        5x5    0.1            0.5  random_init  0.281640         25
# 1        5x5    0.9            0.6  random_init  0.282941         25
# 2        5x5    0.6            0.8  random_init  0.298429         25
# 3        5x5    0.1            0.7  random_init  0.299586         25
# 4        5x5    0.2            0.8  random_init  0.302995         25
# ..       ...    ...            ...          ...       ...        ...
# 319      2x2    0.5            0.9  random_init  0.851557          4
# 320      2x2    0.6            0.9  random_init  0.851558          4
# 321      2x2    0.7            0.9  random_init  0.851563          4
# 322      2x2    0.8            0.9  random_init  0.851601          4
# 323      2x2    0.9            0.9  random_init  0.851848          4
#
# [324 rows x 6 columns]

# %%
df_res.to_csv("minisom2_result.csv", index = False, header = True)

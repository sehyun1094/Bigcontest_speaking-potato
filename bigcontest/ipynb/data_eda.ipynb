# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../../../../bigcontest/data/preprocessed/data.csv")

# %%
data_100 = data.loc[data["loan_limit_100million"],:]

# %%
plt.hist(data_100["purpose"])
# Out:
# (array([ 914., 3650.,  533.,    0., 1650.,  823.,    0.,  490.,  431.,
#           99.]),
#  array([0. , 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
pd.crosstab(data["income_type"], data["employment_type"], normalize = 'all')
# Out:
# employment_type       계약직        기타       일용직       정규직
# income_type
# EARNEDINCOME     0.073201  0.006532  0.008760  0.760345
# EARNEDINCOME2    0.011421  0.006266  0.003840  0.024379
# FREELANCER       0.000405  0.023143  0.000018  0.000559
# OTHERINCOME      0.000030  0.029457  0.000020  0.000197
# PRACTITIONER     0.001919  0.000767  0.000591  0.011990
# PRIVATEBUSINESS  0.000969  0.014483  0.000252  0.020452

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
plt.hist(data['loan_limit'])
plt.title('신용점수 별 대출한도')
plt.show()

# %%
plt.scatter(data["credit_score"], np.log10(data['loan_rate']), s = 1/2)
plt.title('신용점수 별 대출이자')
plt.show()
